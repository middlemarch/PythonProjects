# %% [markdown]
# ### Importing libraries, the second two relate to the heatmap- the final is what's called a 'magic' and tells Jupyter to display the images in place, rather than just saving them somewhere

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### This file was pretty standard so didn't require any particular parameters to pass to the read_csv function

# %%
df= pd.read_csv('C:/Users/rtfly/Documents/HDip/Web_DataMining/HR_comma_sep.csv')
df.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
# 5                   3              0     1                      0  sales
# 6                   4              0     1                      0  sales
# 7                   5              0     1                      0  sales
# 8                   5              0     1                      0  sales
# 9                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low
# 5     low
# 6     low
# 7     low
# 8     low
# 9     low

# %% [markdown]
# ### This will return the rows x columns count

# %%
df.shape
# Out:
# (14999, 10)

# %% [markdown]
# ### The .unique() method will return all unique values for a given variable, 'sales' in this case

# %%
df.sales.unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %% [markdown]
# ### Creating a dictionary will allow you to map values in order to replace string data with integers, remembering that there are a few ML algorithms that won't accept strings.

# %%
sales_dict = {'sales':1, 
              'accounting':2, 
              'hr':3, 
              'technical':4, 
              'support':5, 
              'management':6, 
              'IT':7, 
              'product_mng':8,
              'marketing':9,
              'RandD':10
              }

# %% [markdown]
# ### The .replace() function is a really flexible mapping tool, and can accept a dictionary as a parameter- the 'inplace=True' ensures that the changes affect the dataframe you're using. If you made this command without that, it would just show you what the df would look like with the changes, but the original one will remain the same. It would be the same as df = df.replace(x, y) but is more efficient in that it doesn't write a whole new dataframe.

# %%
df.replace({"sales": sales_dict}, inplace=True)

# %%
df.salary.unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
salary_dict = {'low':1,
               'medium':2,
               'high':3
               }

# %%
df.replace({"salary": salary_dict}, inplace=True)

# %% [markdown]
# ### This is just a summary function, but will throw NaN for any variables that have missing values, so it's a good way to test for those. I'm happy to say, our data is CLEAN!

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years         sales        salary
# count           14999.000000  14999.000000  14999.000000
# mean                0.021268      4.339823      1.594706
# std                 0.144281      2.820837      0.637183
# min                 0.000000      1.000000      1.000000
# 25%                 0.000000      1.000000      1.000000
# 50%                 0.000000      4.000000      2.000000
# 75%                 0.000000      7.000000      2.000000
# max                 1.000000     10.000000      3.000000

# %% [markdown]
# ### Now, the heat map. It's just a few lines of code once the data is clean. Did not drop 'left' at this stage, no harm in giving ourselves a clue as to what to go for. Nothing much else anyway. But it's negatively correlated to satisfaction level, meaning that that's a major driver. So even if you're being headhunted and are some kinda tech wizard, you might still stay if you're happy. I guess we need to find out what makes staff dissatisfied in the first place!

# %%
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           annot=True,
           annot_kws={"size":8})

# %%
leavers = df['left'] == 1

# %%
df_left = df[leavers]
df_left.shape
# Out:
# (3571, 10)

# %%
stayers = df['left'] == 0

# %%
df_stay = df[stayers]
df_stay.shape
# Out:
# (11428, 10)

# %% [markdown]
# ### This is pretty clear, we've split on the 'left' value so it's now redundant and only carries one value. Let's drop it. This command will throw a warning because it's afraid this command will 'write back' to the original dataframe: it won't!

# %%
df_left.drop('left', axis=1, inplace=True)

# %%
df_stay.drop('left', axis=1, inplace=True)

# %% [markdown]
# ### Here's proof! Variable 'left' still exists in the original dataframe.

# %%
df.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0      1
# 1                   6              0     1                      0      1
# 2                   4              0     1                      0      1
# 3                   5              0     1                      0      1
# 4                   3              0     1                      0      1
# 5                   3              0     1                      0      1
# 6                   4              0     1                      0      1
# 7                   5              0     1                      0      1
# 8                   5              0     1                      0      1
# 9                   3              0     1                      0      1
#
#    salary
# 0       1
# 1       2
# 2       2
# 3       1
# 4       1
# 5       1
# 6       1
# 7       1
# 8       1
# 9       1

# %% [markdown]
# ### BORING!!! (these are the stayers...)

# %%
corr_st = df_stay.corr()
sns.heatmap(corr_st, 
            xticklabels=corr_st.columns.values,
            yticklabels=corr_st.columns.values,
           annot=True,
           annot_kws={"size":8})

# %% [markdown]
# ### Aha! This is actually interesting :) These are the characteristics of quitters, folks!

# %%
corr_lv = df_left.corr()
sns.heatmap(corr_lv, 
            xticklabels=corr_lv.columns.values,
            yticklabels=corr_lv.columns.values,
           annot=True,
           annot_kws={"size":8})

# %% [markdown]
# ### This is how you'd drop the target variable 'left' from the original df, again the inplace parameter is set to True, otherwise it won't stick. Commented out so it won't run.

# %%
# df.drop('left', axis=1, inplace=True)
